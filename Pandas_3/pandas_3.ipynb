# %%
import pandas as pd

# %%
melb_data = pd.read_csv('data/melb_data_fe.csv')

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_data['Date']
# Out:
# 0        2016-03-12
# 1        2016-04-02
# 2        2017-04-03
# 3        2017-04-03
# 4        2016-04-06
#             ...
# 13575    2017-08-26
# 13576    2017-08-26
# 13577    2017-08-26
# 13578    2017-08-26
# 13579    2017-08-26
# Name: Date, Length: 13580, dtype: object

# %%
melb_data['Date'] = pd.to_datetime(melb_data['Date'], dayfirst=True)
melb_data['Date'].dt.quarter.value_counts()
# Out:
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: Date, dtype: int64

# %%
exclude_list = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']

# %%
i = 0
for col in melb_data.columns:
    if (melb_data[col].nunique() < 150) and col not in exclude_list:
        melb_data[col] = melb_data[col].astype('category')
        i += 1
        
i
# Out:
# 10

# %%
melb_data.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_data.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_data.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_data['AreaRatio'] < -0.8
mask2 = melb_data['Type'] == 'townhouse'
mask3 = melb_data['SellerG'] == 'McGrath'
melb_data[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_data.sort_values(by=['AreaRatio'], ascending=False, ignore_index=True).loc[1558, 'BuildingArea']
# Out:
# 126.0

# %%
mask = (melb_data['Type'] == 'townhouse') & (melb_data['Rooms'] > 2)
melb_data[mask].sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).loc[18, 'Price']
# Out:
# 1300000.0

# %%
melb_data.groupby(by='Type').mean()
# Out:
# C:\Users\Питерские котики\AppData\Local\Temp\ipykernel_44632\1129381730.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   melb_data.groupby(by='Type').mean()
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_data.groupby(by='Type', as_index=False).mean()
# Out:
# C:\Users\Питерские котики\AppData\Local\Temp\ipykernel_44632\3413170649.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   melb_data.groupby(by='Type', as_index=False).mean()
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
round(melb_data.groupby(by='Type')['Price'].mean(), 2)
# Out:
# Type
# house        1242664.76
# townhouse     933735.05
# unit          605127.48
# Name: Price, dtype: float64

# %%
melb_data.groupby(by='Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_data.groupby('MonthSale')['Price'].agg(['count', 'mean', 'max']).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_data.groupby('MonthSale')['Price'].agg('describe')
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# ...

# %%
melb_data.groupby('Regionname')['SellerG'].agg(['nunique', set])
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {McGrath, Fletchers, Nelson, Biggin, Purplebri...
# Eastern Victoria            {Eview, HAR, C21, Fletchers, McGrath, O'Brien,...
# Northern Metropolitan       {Burnham, LITTLE, Sweeney, McGrath, Fletchers,...
# Northern Victoria           {LITTLE, HAR, YPA, Buckingham, McGrath, Barry,...
# South-Eastern Metropolitan  {Fletchers, McGrath, O'Brien, Nelson, Chisholm...
# Southern Metropolitan       {LITTLE, Fletchers, McGrath, O'Brien, Nelson, ...
# ...

# %%
melb_data.groupby(by='Rooms')['Price'].mean()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 7     1.920700e+06
# 8     1.602750e+06
# 10    9.000000e+05
# Name: Price, dtype: float64

# %%
melb_data.groupby(by='Regionname')['Lattitude'].std().sort_values(ascending=True)
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
melb_data['Date']
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
mask1 = melb_data['Date'] >= pd.to_datetime('2017-05-1')
mask2 = melb_data['Date'] <= pd.to_datetime('2017-09-1')

melb_data[mask1 & mask2].groupby(by='SellerG')['Price'].sum().sort_values()
# Out:
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# Purplebricks      23401000.0
# O'Brien           23855508.0
# HAR               25568000.0
# Village           26473000.0
# RW                29261000.0
# Raine             30687700.0
# Stockdale         35409800.0
# Sweeney           36882750.0
# Gary              39138400.0
# Hodges            43231000.0
# YPA               46354350.0
# Miles             47582000.0
# ...

# %%
melb_data.groupby(by='Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_data.groupby(by=['Rooms', 'Type'])['Price'].mean().round(2)
# объект Series
# Out:
# Rooms  Type
# 1      house         866865.52
#        townhouse     592704.55
#        unit          389928.92
# 2      house        1017237.81
#        townhouse     710158.46
#        unit          610490.51
# 3      house        1109233.38
#        townhouse     984708.66
#        unit          850596.34
# 4      house        1462283.08
#        townhouse    1217092.00
#        unit         1037476.19
# 5      house        1877326.92
#        townhouse    1035000.00
#        unit                NaN
# 6      house        1869507.58
#        townhouse           NaN
#        unit          520000.00
# 7      house        1920700.00
#        townhouse           NaN
#        unit                NaN
# 8      house        1510285.71
#        townhouse           NaN
#        unit         2250000.00
# 10     house         900000.00
#        townhouse           NaN
#        unit                NaN
# Name: Price, dtype: float64

# %%
melb_data.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# groupby(by= ...) можно не писать by
# Out:
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_data.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_data.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'

)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_data.pivot_table(
    values='Landsize',
    columns='Type',
    index='Regionname',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
melb_data.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    #aggfunc='mean'
    aggfunc=['median', 'mean'],
    fill_value=0
).round()
# Out:
#                              median                mean
# Weekend                           0        1          0          1
# Regionname
# Eastern Metropolitan         990000  1020000  1082900.0  1113325.0
# Eastern Victoria             735000   653000   775923.0   675300.0
# Northern Metropolitan        800000   810000   881881.0   905957.0
# Northern Victoria            600000   530750   641455.0   577733.0
# South-Eastern Metropolitan   880000   837000   918167.0   924740.0
# Southern Metropolitan       1185000  1281000  1321720.0  1397831.0
# Western Metropolitan         793250   793000   894947.0   852645.0
# Western Victoria             386750   402500   391750.0   399448.0

# %%
melb_data[(melb_data['Weekend'] == 0) & (melb_data['Regionname'] == 'Eastern Metropolitan')]['Price'].agg('describe').round(2)
# Out:
# count        447.00
# mean     1082899.59
# std       461144.44
# min       288000.00
# 25%       753500.00
# 50%       990000.00
# 75%      1320000.00
# max      3020000.00
# Name: Price, dtype: float64

# %%
pivot = melb_data.pivot_table(
    values='Price',
    index=['Method', 'Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)

pivot
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %%
pivot = melb_data.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
pivot
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
pivot.index
# Out:
# CategoricalIndex(['Eastern Metropolitan', 'Eastern Victoria',
#                   'Northern Metropolitan', 'Northern Victoria',
#                   'South-Eastern Metropolitan', 'Southern Metropolitan',
#                   'Western Metropolitan', 'Western Victoria'],
#                  categories=['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan', 'Northern Victoria', 'South-Eastern Metropolitan', 'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'], ordered=False, dtype='category', name='Regionname')

# %%
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
pivot['mean']['unit']
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]

# %%
list(filtered_pivot.index)
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
pivot = melb_data.pivot_table(
    values='BuildingArea',
    index=['Rooms'],
    columns='Type',
    fill_value=0,
    aggfunc='median'
).round()

pivot
# Out:
# Type   house  townhouse   unit
# Rooms
# 1      126.0       88.0   70.0
# 2      126.0      114.0  110.0
# 3      126.0      126.0  126.0
# 4      141.0      160.0  126.0
# 5      177.0      152.0    0.0
# 6      126.0        0.0  171.0
# 7      216.0        0.0    0.0
# 8      126.0        0.0  126.0
# 10     126.0        0.0    0.0

# %%
pivot.max(axis=1)
# Out:
# Rooms
# 1     126.0
# 2     126.0
# 3     126.0
# 4     160.0
# 5     177.0
# 6     171.0
# 7     216.0
# 8     126.0
# 10    126.0
# dtype: float64

# %%
pivot_2 = pivot.max(axis=0)

# %%
for ind in pivot_2.index:
    if pivot_2[ind] == pivot_2.max(): print(ind)
# Out:
# house

# %%
melb_data.pivot_table(
    values='Price',
    aggfunc='median',
    index='SellerG',
    columns='Type',
    fill_value=0
)['unit'].sort_values(ascending=False).index[0]
# Out:
# 'Nick'

# %%
movies = pd.read_csv('data/movies_data/movies.csv')

# %%
movies['movieId'].nunique()
# Out:
# 9742

# %%
ratings1 = pd.read_csv('data/movies_data/ratings1.csv')

# %%
ratings1['userId'].nunique()
# Out:
# 274

# %%
dates = pd.read_csv('data/movies_data/dates.csv')
dates.head()
# Out:
#                   date
# 0  2000-07-30 18:45:03
# 1  2000-07-30 18:20:47
# 2  2000-07-30 18:37:04
# 3  2000-07-30 19:03:35
# 4  2000-07-30 18:48:51

# %%
print(dates['date'].dtype)

dates['date'] = pd.to_datetime(dates['date'], dayfirst=False, yearfirst=True)
print(dates['date'].dtype)
# Out:
# object
# datetime64[ns]

# %%
dates['date'].dt.day.head()
# Out:
# 0    30
# 1    30
# 2    30
# 3    30
# 4    30
# Name: date, dtype: int64

# %%
dates['date'].dt.year.value_counts()
# Out:
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: date, dtype: int64

# %%
ratings2 = pd.read_csv('data/movies_data/ratings2.csv')

# %%
len(ratings1) + len(ratings2)
# Out:
# 100837

# %%
ratings = pd.concat(
    [ratings1, ratings2],
    ignore_index=True
)
len(ratings)
# Out:
# 100837

# %%
ratings.shape
# Out:
# (100837, 3)

# %%
dates.shape
# Out:
# (100836, 1)

# %%
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
ratings.shape
# Out:
# (100836, 3)

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
dates.head(3)
# Out:
#                  date
# 0 2000-07-30 18:45:03
# 1 2000-07-30 18:20:47
# 2 2000-07-30 18:37:04

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
ratings_dates.tail(7)
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %%
os.listdir('data/')
# Out:
# ['melb_data_fe.csv',
#  'movies_data',
#  'orders_and_products',
#  'ratings_movies.csv']

# %%
def concat_user_files(path):
    files_list = sorted(os.listdir(path))
    
    file_df = []
    
    for file in files_list:
        if file.count('csv'): 
            file_df.append(pd.read_csv(path+file))
            
    return pd.concat(file_df).drop_duplicates(ignore_index=True)

# %%
file_df = concat_user_files('data/')
file_df
# Out:
#             Suburb  Rooms   Type      Price Method SellerG        Date  \
# 0       Abbotsford    2.0  house  1480000.0      S  Biggin  2016-03-12
# 1       Abbotsford    2.0  house  1035000.0      S  Biggin  2016-04-02
# 2       Abbotsford    3.0  house  1465000.0     SP  Biggin  2017-04-03
# 3       Abbotsford    3.0  house   850000.0     PI  Biggin  2017-04-03
# 4       Abbotsford    4.0  house  1600000.0     VB  Nelson  2016-04-06
# ...            ...    ...    ...        ...    ...     ...         ...
# 114411         NaN    NaN    NaN        NaN    NaN     NaN         NaN
# 114412         NaN    NaN    NaN        NaN    NaN     NaN         NaN
# 114413         NaN    NaN    NaN        NaN    NaN     NaN         NaN
# 114414         NaN    NaN    NaN        NaN    NaN     NaN         NaN
# 114415         NaN    NaN    NaN        NaN    NaN     NaN         NaN
#
#         Distance  Postcode  Bedroom  ...  WeekdaySale  StreetType  Weekend  \
# ...

# %%
ratings_dates.head(3)
# Out:
#    userId  movieId  rating                date
# 0       1        1     4.0 2000-07-30 18:45:03
# 1       1        3     4.0 2000-07-30 18:20:47
# 2       1        6     4.0 2000-07-30 18:37:04

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left',
)

joined_false
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
movies.set_index('movieId')
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)

joined.head(3)
# Out:
#    userId  movieId  rating                date                    title  \
# 0       1        1     4.0 2000-07-30 18:45:03         Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47  Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04              Heat (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)

merged.head()
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
joined.shape
# Out:
# (100836, 6)

# %%
merged.shape
# Out:
# (100836, 6)

# %%
ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
).tail()
# Out:
#         userId  movieId  rating date                               title  \
# 100849     NaN    30892     NaN  NaT  In the Realms of the Unreal (2004)
# 100850     NaN    32160     NaN  NaT            Twentieth Century (1934)
# 100851     NaN    32371     NaN  NaT           Call Northside 777 (1948)
# 100852     NaN    34482     NaN  NaT        Browning Version, The (1951)
# 100853     NaN    85565     NaN  NaT                  Chalet Girl (2011)
#
#                        genres
# 100849  Animation|Documentary
# 100850                 Comedy
# 100851  Crime|Drama|Film-Noir
# 100852                  Drama
# 100853         Comedy|Romance

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
# автоматически удаляет дубли

merge_ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})

# %%
merged = items_df.merge(purchase_df, how='inner')

income_sr = merged['price'] * merged['stock_count']
income = income_sr.sum()
income
# Out:
# 19729490

# %%
melb_data[['AgeBuilding', 'AreaRatio']]
# Out:
#        AgeBuilding  AreaRatio
# 0               46  -0.231707
# 1              116  -0.327660
# 2              117   0.056338
# 3               47   0.145455
# 4                2   0.083969
# ...            ...        ...
# 13575           36  -0.676093
# 13576           22  -0.429185
# 13577           20  -0.551601
# 13578           97  -0.693060
# 13579           97  -0.527426
#
# [13580 rows x 2 columns]
